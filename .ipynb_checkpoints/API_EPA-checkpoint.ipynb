# %%
import pandas as pd
import numpy as np
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
from config import api_key
from citipy import citipy
from pprint import pprint

# %%
# Save config information.
url = "https://apps.bea.gov/api/data?&UserID=213A4AF7-DC33-48FC-AAC2-97E6B3D581B9&method=GETDATASETLIST&ResultFormat=JSON"

response = requests.get(url).json()
pprint(response)

response['BEAAPI']['Results']['Dataset'][1]
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'METHOD',
#                                           'ParameterValue': 'GETDATASETLIST'},
#                                          {'ParameterName': 'RESULTFORMAT',
#                                           'ParameterValue': 'JSON'},
#                                          {'ParameterName': 'USERID',
#                                           'ParameterValue': '213A4AF7-DC33-48FC-AAC2-97E6B3D581B9'}]},
#             'Results': {'Dataset': [{'DatasetDescription': 'The RegionalData '
#                                                            'dataset is '
#                                                            'obsolete. Please '
#                                                            'use the Regional '
#                                                            'dataset. See API '
#                                                            'documentation at '
# ...

# %%
url = "https://apps.bea.gov/api/data?&UserID=213A4AF7-DC33-48FC-AAC2-97E6B3D581B9&method=GetData&datasetname=Regional&ResultFormat=JSON"
response = requests.get(url).json()
pprint(response)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'METHOD',
#                                           'ParameterValue': 'GETDATA'},
#                                          {'ParameterName': 'DATASETNAME',
#                                           'ParameterValue': 'REGIONAL'},
#                                          {'ParameterName': 'USERID',
#                                           'ParameterValue': '213A4AF7-DC33-48FC-AAC2-97E6B3D581B9'},
#                                          {'ParameterName': 'RESULTFORMAT',
#                                           'ParameterValue': 'JSON'}]},
#             'Results': {'Error': {'APIErrorCode': '40',
#                                   'APIErrorDescription': 'The dataset '
#                                                          'requested requires '
#                                                          'parameters that were '
#                                                          'missing from the '
# ...

# %%
#url = "http://apps.bea.gov/api/data?&UserID=213A4AF7-DC33-48FC-AAC2-97E6B3D581B9&method=GetData&datasetname=Regional&TableName=SAINC1&GeoFIPS=STATE&LineCode=3&Year=2013&ResultFormat=JSON"

url = "https://apps.bea.gov/api/data/?&UserID=213A4AF7-DC33-48FC-AAC2-97E6B3D581B9&method=GetData&DataSetName=NIPA&TableName=T10101&Frequency=A,Q&Year=2014&ResultFormat=JSON"
response = requests.get(url).json()
pprint(response)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'FREQUENCY',
#                                           'ParameterValue': 'A,Q'},
#                                          {'ParameterName': 'METHOD',
#                                           'ParameterValue': 'GETDATA'},
#                                          {'ParameterName': 'USERID',
#                                           'ParameterValue': '213A4AF7-DC33-48FC-AAC2-97E6B3D581B9'},
#                                          {'ParameterName': 'TABLENAME',
#                                           'ParameterValue': 'T10101'},
#                                          {'ParameterName': 'DATASETNAME',
#                                           'ParameterValue': 'NIPA'},
#                                          {'ParameterName': 'YEAR',
#                                           'ParameterValue': '2014'},
#                                          {'ParameterName': 'RESULTFORMAT',
# ...

# %%
url = "https://apps.bea.gov/api/data/?&UserID=213A4AF7-DC33-48FC-AAC2-97E6B3D581B9&method=GetData&DataSetName=GDPbyIndustry&Frequency=A,Q&Year=2014&ResultFormat=JSON"
response = requests.get(url).json()
pprint(response)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'FREQUENCY',
#                                           'ParameterValue': 'A,Q'},
#                                          {'ParameterName': 'METHOD',
#                                           'ParameterValue': 'GETDATA'},
#                                          {'ParameterName': 'RESULTFORMAT',
#                                           'ParameterValue': 'JSON'},
#                                          {'ParameterName': 'YEAR',
#                                           'ParameterValue': '2014'},
#                                          {'ParameterName': 'USERID',
#                                           'ParameterValue': '213A4AF7-DC33-48FC-AAC2-97E6B3D581B9'},
#                                          {'ParameterName': 'DATASETNAME',
#                                           'ParameterValue': 'GDPBYINDUSTRY'}]},
#             'Results': {'Error': {'APIErrorCode': '40',
# ...

# %%
URL = "http://apps.bea.gov/api/data?&UserID=213A4AF7-DC33-48FC-AAC2-97E6B3D581B9&method=GetData&datasetname=RegionalIncome&TableName='data sets'&GeoFIPS=NJ&LineCode=3&Year=2013&ResultFormat=JSON"
response = requests.get(url).json()
pprint(response)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'YEAR',
#                                           'ParameterValue': '2014'},
#                                          {'ParameterName': 'FREQUENCY',
#                                           'ParameterValue': 'A,Q'},
#                                          {'ParameterName': 'DATASETNAME',
#                                           'ParameterValue': 'GDPBYINDUSTRY'},
#                                          {'ParameterName': 'RESULTFORMAT',
#                                           'ParameterValue': 'JSON'},
#                                          {'ParameterName': 'USERID',
#                                           'ParameterValue': '213A4AF7-DC33-48FC-AAC2-97E6B3D581B9'},
#                                          {'ParameterName': 'METHOD',
#                                           'ParameterValue': 'GETDATA'}]},
#             'Results': {'Error': {'APIErrorCode': '40',
# ...

# %%
url = "https://apps.bea.gov/api/data?&UserID=213A4AF7-DC33-48FC-AAC2-97E6B3D581B9&method=getparameterlist&datasetname=RegionalIncome&ResultFormat=JSON"
response = requests.get(url).json()
pprint(response)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'USERID',
#                                           'ParameterValue': '213A4AF7-DC33-48FC-AAC2-97E6B3D581B9'},
#                                          {'ParameterName': 'DATASETNAME',
#                                           'ParameterValue': 'REGIONALINCOME'},
#                                          {'ParameterName': 'METHOD',
#                                           'ParameterValue': 'GETPARAMETERLIST'},
#                                          {'ParameterName': 'RESULTFORMAT',
#                                           'ParameterValue': 'JSON'}]},
#             'Results': {'Parameter': [{'MultipleAcceptedFlag': '1',
#                                        'ParameterDataType': 'string',
#                                        'ParameterDescription': 'Comma-delimited '
#                                                                'list of '
# ...

# %%
url = "https://apps.bea.gov/api/data?&UserID=213A4AF7-DC33-48FC-AAC2-97E6B3D581B9&method=getparameterlist&datasetname=RegionalIncome&ResultFormat=JSON"
response = requests.get(url).json()
pprint(response)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...
